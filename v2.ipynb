# %% [markdown]
# # Loading data

# %%
#%pip install gymnasium
import gymnasium as gym
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

# %% [markdown]
# # Setting up the environment

# %%
env = gym.make("Pendulum-v1")

print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# Observation space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# Action space: Box(-2.0, 2.0, (1,), float32)

# %% [markdown]
# # Discretizing the observation space

# %%
import numpy as np
from collections import defaultdict

obs_bins = [
    np.linspace(-1, 1, 21),
    np.linspace(-1, 1, 21),
    np.linspace(-8, 8, 21),
]

action_vals = np.linspace(-2, 2, 17)

def discretize_observation(obs):
    return tuple(np.digitize(obs[i], obs_bins[i]) for i in range(len(obs)))

# %% [markdown]
# # Initializing the Q-Table

# %%
from collections import defaultdict

Q = defaultdict(lambda: np.zeros(len(action_vals)))

# %% [markdown]
# # Monte Carlo

# %%
num_episodes = 100000
gamma = 0.99
alpha = 0.1
epsilon = 1.0
epsilon_decay = 0.9995
epsilon_min = 0.05

returns = []
window = 100

for episode in range(num_episodes):
    obs, _ = env.reset()
    state = discretize_observation(obs)
    trajectory = []
    done = False

    while not done:
        if np.random.rand() < epsilon:
            action_idx = np.random.randint(len(action_vals))
        else:
            action_idx = np.argmax(Q[state])

        action = np.array([action_vals[action_idx]])
        next_obs, reward, terminated, truncated, _ = env.step(action)
        next_state = discretize_observation(next_obs)

        trajectory.append((state, action_idx, reward))
        state = next_state
        done = terminated or truncated

    G = 0
    visited = set()
    for t in reversed(range(len(trajectory))):
        s, a, r = trajectory[t]
        G = r + gamma * G
        if (s, a) not in visited:
            Q[s][a] += alpha * (G - Q[s][a])
            visited.add((s, a))

    episode_return = sum(r for _, _, r in trajectory)
    returns.append(episode_return)

    epsilon = max(epsilon_min, epsilon * epsilon_decay)

    if (episode + 1) % 1000 == 0:
        avg_return = np.mean(returns[-window:])
        print(f"Episode {episode + 1}, average return (last {window}): {avg_return:.2f}")
# Out:
# Episode 1000, average return (last 100): -1088.42
# Episode 2000, average return (last 100): -1101.02
# Episode 3000, average return (last 100): -686.98
# Episode 4000, average return (last 100): -530.25
# Episode 5000, average return (last 100): -428.46
# Episode 6000, average return (last 100): -319.61
# Episode 7000, average return (last 100): -292.23
# Episode 8000, average return (last 100): -316.74
# Episode 9000, average return (last 100): -327.17
# Episode 10000, average return (last 100): -280.68
# Episode 11000, average return (last 100): -284.43
# Episode 12000, average return (last 100): -359.68
# Episode 13000, average return (last 100): -312.31
# Episode 14000, average return (last 100): -324.19
# Episode 15000, average return (last 100): -336.99
# Episode 16000, average return (last 100): -368.96
# Episode 17000, average return (last 100): -289.85
# Episode 18000, average return (last 100): -308.27
# Episode 19000, average return (last 100): -344.16
# Episode 20000, average return (last 100): -402.22
# Episode 21000, average return (last 100): -413.42
# Episode 22000, average return (last 100): -383.43
# Episode 23000, average return (last 100): -341.32
# Episode 24000, average return (last 100): -367.84
# Episode 25000, average return (last 100): -337.51
# Episode 26000, average return (last 100): -250.22
# Episode 27000, average return (last 100): -360.35
# Episode 28000, average return (last 100): -270.01
# Episode 29000, average return (last 100): -361.12
# Episode 30000, average return (last 100): -254.45
# Episode 31000, average return (last 100): -303.82
# Episode 32000, average return (last 100): -306.51
# Episode 33000, average return (last 100): -278.25
# Episode 34000, average return (last 100): -309.95
# Episode 35000, average return (last 100): -358.15
# Episode 36000, average return (last 100): -302.05
# Episode 37000, average return (last 100): -303.08
# Episode 38000, average return (last 100): -312.70
# Episode 39000, average return (last 100): -293.33
# Episode 40000, average return (last 100): -362.19
# Episode 41000, average return (last 100): -393.51
# Episode 42000, average return (last 100): -413.44
# Episode 43000, average return (last 100): -307.10
# Episode 44000, average return (last 100): -291.14
# Episode 45000, average return (last 100): -588.36
# Episode 46000, average return (last 100): -275.58
# Episode 47000, average return (last 100): -269.21
# Episode 48000, average return (last 100): -309.66
# Episode 49000, average return (last 100): -492.66
# Episode 50000, average return (last 100): -464.62
# Episode 51000, average return (last 100): -338.70
# Episode 52000, average return (last 100): -334.09
# Episode 53000, average return (last 100): -327.74
# Episode 54000, average return (last 100): -291.38
# Episode 55000, average return (last 100): -326.93
# Episode 56000, average return (last 100): -319.78
# Episode 57000, average return (last 100): -272.46
# Episode 58000, average return (last 100): -332.46
# Episode 59000, average return (last 100): -269.82
# Episode 60000, average return (last 100): -320.39
# Episode 61000, average return (last 100): -330.03
# Episode 62000, average return (last 100): -342.19
# Episode 63000, average return (last 100): -293.14
# Episode 64000, average return (last 100): -301.29
# Episode 65000, average return (last 100): -320.33
# Episode 66000, average return (last 100): -355.13
# Episode 67000, average return (last 100): -286.21
# Episode 68000, average return (last 100): -293.77
# Episode 69000, average return (last 100): -345.94
# Episode 70000, average return (last 100): -318.45
# Episode 71000, average return (last 100): -275.67
# Episode 72000, average return (last 100): -316.15
# Episode 73000, average return (last 100): -335.49
# Episode 74000, average return (last 100): -267.84
# Episode 75000, average return (last 100): -230.89
# Episode 76000, average return (last 100): -302.13
# Episode 77000, average return (last 100): -345.50
# Episode 78000, average return (last 100): -274.29
# Episode 79000, average return (last 100): -307.08
# Episode 80000, average return (last 100): -233.75
# Episode 81000, average return (last 100): -312.02
# Episode 82000, average return (last 100): -239.43
# Episode 83000, average return (last 100): -270.90
# Episode 84000, average return (last 100): -267.31
# Episode 85000, average return (last 100): -299.13
# Episode 86000, average return (last 100): -291.69
# Episode 87000, average return (last 100): -211.15
# Episode 88000, average return (last 100): -286.70
# Episode 89000, average return (last 100): -222.72
# Episode 90000, average return (last 100): -310.61
# Episode 91000, average return (last 100): -312.31
# Episode 92000, average return (last 100): -255.87
# Episode 93000, average return (last 100): -240.93
# Episode 94000, average return (last 100): -273.69
# Episode 95000, average return (last 100): -298.93
# Episode 96000, average return (last 100): -237.15
# Episode 97000, average return (last 100): -314.48
# Episode 98000, average return (last 100): -231.24
# Episode 99000, average return (last 100): -232.12
# Episode 100000, average return (last 100): -256.37

# %% [markdown]
# # Evaluation

# %%
eval_episodes = 1000
total_return = 0.0

for _ in range(eval_episodes):
    obs, _ = env.reset()
    state = discretize_observation(obs)
    done = False
    G = 0
    while not done:
        action_idx = np.argmax(Q[state])
        action = np.array([action_vals[action_idx]])
        obs, reward, terminated, truncated, _ = env.step(action)
        state = discretize_observation(obs)
        G += reward
        done = terminated or truncated
    total_return += G

average_return = total_return / eval_episodes
print(f"Average return over {eval_episodes} eval episodes: {average_return:.2f}")
# Out:
# Average return over 1000 eval episodes: -240.85

# %% [markdown]
# # Plotting the metrics

# %%
moving_avg = [np.mean(returns[max(0, i - window):i + 1]) for i in range(len(returns))]
plt.figure(figsize=(12, 6))
plt.plot(moving_avg)
plt.xlabel("Episode")
plt.ylabel(f"Moving Average Return (window={window})")
plt.title("Training Progress")
plt.show()
